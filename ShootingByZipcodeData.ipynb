# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import gmaps
import gmaps.datasets
import zipcodes
import censusgeocode as cg

from census import Census
from us import states

# census key
from api_keys import (ckey, gkey)

# Census API Key
c = Census(ckey, year=2013)

# %%
# Read Shooting File and store into Pandas data frame
shooting14_data = pd.read_csv("DataFiles/2014.csv")
shooting15_data = pd.read_csv("DataFiles/2015.csv")
shooting16_data = pd.read_csv("DataFiles/2016.csv")
shooting17_data = pd.read_csv("DataFiles/2017.csv")
shooting18_data = pd.read_csv("DataFiles/2018.csv")

# %%
# Merge dataframes
shooting_data = pd.merge(shooting14_data,shooting15_data, how="outer")
shooting_data = pd.merge(shooting_data, shooting16_data, how="outer")
shooting_data = pd.merge(shooting_data, shooting17_data, how="outer")
#shooting_data = pd.merge(shooting_data, shooting18_data, how="outer")

# %%
# Find number of incidents in original
len(shooting_data)
# Out:
# 1331

# %%
# Format dates into datetimes and preview to verify
shooting_data["Incident Date"] = pd.to_datetime(shooting_data["Incident Date"])
shooting_data.head()
# Out:
#   Incident Date       State  City Or County  \
# 0    2014-12-29   Louisiana     New Orleans
# 1    2014-12-27  California     Los Angeles
# 2    2014-12-27  California      Sacramento
# 3    2014-12-26    Illinois  East St. Louis
# 4    2014-12-24    Missouri     Saint Louis
#
#                                Address  # Killed  # Injured  Operations
# 0                  Poydras and Bolivar         0          4         NaN
# 1  8800 block of South Figueroa Street         1          3         NaN
# 2             4000 block of May Street         0          4         NaN
# 3          2500 block of Summit Avenue         1          3         NaN
# 4                        18th and Pine         1          3         NaN

# %%
# Utilize dictionary to change State names to abbreviations to use in geocoding
us_state_abbrev = {'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO','Connecticut': 'CT',
    'Delaware': 'DE','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI','Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA',
    'Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA','Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI',
    'Minnesota': 'MN','Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH',
    'New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC','North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK',
    'Oregon': 'OR','Pennsylvania': 'PA','Rhode Island': 'RI','South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN',
    'Texas': 'TX','Utah': 'UT','Vermont': 'VT','Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI',
    'Wyoming': 'WY', 'District of Columbia': 'DC' ,'Puerto Rico': 'PR'}

# Loop through rows to add new column with abbreviations
for index, row in shooting_data.iterrows():
    #shooting2_data["ST"] = us_state_abbrev[shooting_data["State"][index]]
    shooting_data.loc[index, "ST"] = us_state_abbrev[shooting_data["State"][index]]
    
# Preview to verify
shooting_data.head(20)
# Out:
#    Incident Date         State  City Or County  \
# 0     2014-12-29     Louisiana     New Orleans
# 1     2014-12-27    California     Los Angeles
# 2     2014-12-27    California      Sacramento
# 3     2014-12-26      Illinois  East St. Louis
# 4     2014-12-24      Missouri     Saint Louis
# 5     2014-12-23      Kentucky      Winchester
# 6     2014-12-22      Michigan         Detroit
# 7     2014-12-22      New York         Webster
# 8     2014-12-22      Illinois         Chicago
# 9     2014-12-21       Florida        Sarasota
# 10    2014-12-21   Mississippi      Waynesboro
# 11    2014-12-21      Illinois    Calumet City
# 12    2014-12-20      Illinois        Rockford
# 13    2014-12-16    New Jersey       Elizabeth
# 14    2014-12-15  Pennsylvania        Lansdale
# 15    2014-12-14       Florida           Miami
# 16    2014-12-13       Florida           Tampa
# 17    2014-12-12        Oregon        Portland
# 18    2014-12-07       Indiana      South Bend
# 19    2014-12-02      Missouri     Saint Louis
#
#                                 Address  # Killed  # Injured  Operations  ST
# 0                   Poydras and Bolivar         0          4         NaN  LA
# 1   8800 block of South Figueroa Street         1          3         NaN  CA
# 2              4000 block of May Street         0          4         NaN  CA
# 3           2500 block of Summit Avenue         1          3         NaN  IL
# 4                         18th and Pine         1          3         NaN  MO
# 5                      260 Oxford Drive         1          3         NaN  KY
# 6                 Charlevoix and Philip         1          3         NaN  MI
# 7                         191 Lake Road         4          2         NaN  NY
# 8      5700 block of South Green Street         0          5         NaN  IL
# 9                4034 N Washington Blvd         2          2         NaN  FL
# 10                       Central Avenue         1          4         NaN  MS
# 11                 600 block of Escanba         1          8         NaN  IL
# 12        3200 block of Montrose Avenue         4          0         NaN  IL
# 13                          Anna Street         0          4         NaN  NJ
# 14             100 block of West 5th St         7          0         NaN  PA
# 15            1311 Northwest 2nd Avenue         1          4         NaN  FL
# 16                  810 E. Skagway Ave.         0          5         NaN  FL
# 17        717 North Killingsworth Court         0          4         NaN  OR
# 18        16000 block of Roosevelt Road         0          4         NaN  IN
# 19        6000 block of Virginia Avenue         1          5         NaN  MO

# %%
# Identify dataframe information to be used in geocoding
address = shooting_data['Address']
city = shooting_data['City Or County']
state = shooting_data['ST']

# Run through each incident and use Census geocoding to find zipcodes,
# put identifiable incidents' indices into a list to reference later
problems = []

for x in range(0, len(address)):

    # Try/except to identify index of unidentifiable zipcodes
    try:
        zips = cg.onelineaddress(f'{address[x]}, {city[x]}, {state[x]}', returntype='locations')
        zips = zips[0]['addressComponents']['zip']
        shooting_data.loc[x, "Zipcode"] = zips
        print(f"Processing zipcode {x}: {zips}........")
        
    except:
        problems.append(x)
        print(f"Could not find zipcode {x}...........")
        
print(f"---------------\nFinished Processing\n---------------")
# Out:
# Could not find zipcode 0........
# Could not find zipcode 1........
# Processing zipcode 2: 95838........
# Processing zipcode 3: 62205........
# Processing zipcode 4: 63103........
# Processing zipcode 5: 40391........
# Could not find zipcode 6........
# Could not find zipcode 7........
# Could not find zipcode 8........
# Processing zipcode 9: 34234........
# Could not find zipcode 10........
# Processing zipcode 11: 60409........
# Processing zipcode 12: 61101........
# Could not find zipcode 13........
# Could not find zipcode 14........
# Processing zipcode 15: 33136........
# Processing zipcode 16: 33604........
# Processing zipcode 17: 97217........
# Could not find zipcode 18........
# Processing zipcode 19: 63111........
# Processing zipcode 20: 23605........
# Processing zipcode 21: 11212........
# Processing zipcode 22: 37404........
# Processing zipcode 23: 07103........
# Processing zipcode 24: 30315........
# Processing zipcode 25: 38116........
# Could not find zipcode 26........
# Could not find zipcode 27........
# Could not find zipcode 28........
# Could not find zipcode 29........
# Processing zipcode 30: 44106........
# Could not find zipcode 31........
# Could not find zipcode 32........
# Processing zipcode 33: 15122........
# Could not find zipcode 34........
# Could not find zipcode 35........
# Processing zipcode 36: 44305........
# Processing zipcode 37: 79901........
# Processing zipcode 38: 65803........
# Could not find zipcode 39........
# Processing zipcode 40: 91767........
# Could not find zipcode 41........
# Could not find zipcode 42........
# Processing zipcode 43: 94110........
# Could not find zipcode 44........
# Processing zipcode 45: 42211........
# Processing zipcode 46: 98271........
# Could not find zipcode 47........
# Processing zipcode 48: 29829........
# Could not find zipcode 49........
# Could not find zipcode 50........
# Processing zipcode 51: 30092........
# Processing zipcode 52: 30354........
# Could not find zipcode 53........
# Could not find zipcode 54........
# Processing zipcode 55: 13501........
# Could not find zipcode 56........
# Could not find zipcode 57........
# Processing zipcode 58: 32208........
# Could not find zipcode 59........
# Processing zipcode 60: 38108........
# Processing zipcode 61: 91768........
# Processing zipcode 62: 29488........
# Could not find zipcode 63........
# Processing zipcode 64: 19133........
# Could not find zipcode 65........
# Processing zipcode 66: 63107........
# Could not find zipcode 67........
# Processing zipcode 68: 43920........
# Processing zipcode 69: 38606........
# Could not find zipcode 70........
# Could not find zipcode 71........
# Could not find zipcode 72........
# Could not find zipcode 73........
# Processing zipcode 74: 99501........
# Processing zipcode 75: 48223........
# Processing zipcode 76: 32804........
# Processing zipcode 77: 31201........
# Processing zipcode 78: 48505........
# Could not find zipcode 79........
# Could not find zipcode 80........
# Could not find zipcode 81........
# Could not find zipcode 82........
# Processing zipcode 83: 34601........
# Processing zipcode 84: 48205........
# Could not find zipcode 85........
# Processing zipcode 86: 30901........
# Processing zipcode 87: 91340........
# Processing zipcode 88: 38127........
# Could not find zipcode 89........
# Could not find zipcode 90........
# Could not find zipcode 91........
# Could not find zipcode 92........
# Could not find zipcode 93........
# Could not find zipcode 94........
# Processing zipcode 95: 84101........
# Processing zipcode 96: 38112........
# Could not find zipcode 97........
# Could not find zipcode 98........
# Could not find zipcode 99........
# Could not find zipcode 100........
# Processing zipcode 101: 70117........
# Could not find zipcode 102........
# Processing zipcode 103: 92551........
# Could not find zipcode 104........
# Processing zipcode 105: 55401........
# Could not find zipcode 106........
# Could not find zipcode 107........
# Processing zipcode 108: 87107........
# Processing zipcode 109: 93305........
# Could not find zipcode 110........
# Could not find zipcode 111........
# Processing zipcode 112: 63115........
# Could not find zipcode 113........
# Could not find zipcode 114........
# Processing zipcode 115: 75241........
# Could not find zipcode 116........
# Could not find zipcode 117........
# Could not find zipcode 118........
# Processing zipcode 119: 28348........
# Could not find zipcode 120........
# Could not find zipcode 121........
# Could not find zipcode 122........
# Processing zipcode 123: 04072........
# Could not find zipcode 124........
# Processing zipcode 125: 60612........
# Processing zipcode 126: 15104........
# Processing zipcode 127: 07111........
# Processing zipcode 128: 38126........
# Processing zipcode 129: 62204........
# Could not find zipcode 130........
# Processing zipcode 131: 60651........
# Could not find zipcode 132........
# Could not find zipcode 133........
# Processing zipcode 134: 06901........
# Processing zipcode 135: 20002........
# Processing zipcode 136: 91103........
# Processing zipcode 137: 60644........
# Processing zipcode 138: 77388........
# Processing zipcode 139: 02908........
# Could not find zipcode 140........
# Processing zipcode 141: 92410........
# Could not find zipcode 142........
# Processing zipcode 143: 63115........
# Processing zipcode 144: 14215........
# Processing zipcode 145: 77047........
# Processing zipcode 146: 23508........
# Processing zipcode 147: 97233........
# Could not find zipcode 148........
# Processing zipcode 149: 62207........
# Processing zipcode 150: 23523........
# Could not find zipcode 151........
# Could not find zipcode 152........
# Processing zipcode 153: 70116........
# Processing zipcode 154: 63106........
# Could not find zipcode 155........
# Processing zipcode 156: 94531........
# Could not find zipcode 157........
# Could not find zipcode 158........
# Could not find zipcode 159........
# Could not find zipcode 160........
# Could not find zipcode 161........
# Could not find zipcode 162........
# Could not find zipcode 163........
# Could not find zipcode 164........
# Processing zipcode 165: 38114........
# Processing zipcode 166: 20743........
# Processing zipcode 167: 46902........
# Processing zipcode 168: 60466........
# Could not find zipcode 169........
# Could not find zipcode 170........
# Processing zipcode 171: 36467........
# Could not find zipcode 172........
# Processing zipcode 173: 48237........
# Processing zipcode 174: 60644........
# Could not find zipcode 175........
# Processing zipcode 176: 60649........
# Could not find zipcode 177........
# Processing zipcode 178: 95823........
# Could not find zipcode 179........
# Processing zipcode 180: 43607........
# Could not find zipcode 181........
# Could not find zipcode 182........
# Could not find zipcode 183........
# Processing zipcode 184: 70122........
# Processing zipcode 185: 90706........
# Processing zipcode 186: 75224........
# Processing zipcode 187: 44870........
# Could not find zipcode 188........
# Processing zipcode 189: 20018........
# Could not find zipcode 190........
# Processing zipcode 191: 60623........
# Could not find zipcode 192........
# Processing zipcode 193: 38108........
# Processing zipcode 194: 30083........
# Could not find zipcode 195........
# Could not find zipcode 196........
# Processing zipcode 197: 60654........
# Processing zipcode 198: 80033........
# Processing zipcode 199: 72401........
# Processing zipcode 200: 60649........
# Processing zipcode 201: 30144........
# Could not find zipcode 202........
# Processing zipcode 203: 38108........
# Processing zipcode 204: 90043........
# Processing zipcode 205: 60538........
# Could not find zipcode 206........
# Processing zipcode 207: 60637........
# Processing zipcode 208: 66968........
# Processing zipcode 209: 70116........
# Could not find zipcode 210........
# Could not find zipcode 211........
# Processing zipcode 212: 61101........
# Could not find zipcode 213........
# Processing zipcode 214: 01103........
# Could not find zipcode 215........
# Processing zipcode 216: 60624........
# Could not find zipcode 217........
# Could not find zipcode 218........
# Could not find zipcode 219........
# Could not find zipcode 220........
# Processing zipcode 221: 28216........
# Processing zipcode 222: 76011........
# Processing zipcode 223: 90802........
# Could not find zipcode 224........
# Processing zipcode 225: 29418........
# Could not find zipcode 226........
# Could not find zipcode 227........
# Could not find zipcode 228........
# Processing zipcode 229: 43420........
# Could not find zipcode 230........
# Processing zipcode 231: 60644........
# Processing zipcode 232: 94801........
# Could not find zipcode 233........
# Could not find zipcode 234........
# Processing zipcode 235: 48213........
# Could not find zipcode 236........
# Could not find zipcode 237........
# Could not find zipcode 238........
# Processing zipcode 239: 15419........
# Processing zipcode 240: 76164........
# Could not find zipcode 241........
# Processing zipcode 242: 32205........
# Could not find zipcode 243........
# Could not find zipcode 244........
# Could not find zipcode 245........
# Processing zipcode 246: 46407........
# Could not find zipcode 247........
# Could not find zipcode 248........
# Could not find zipcode 249........
# Processing zipcode 250: 70126........
# Processing zipcode 251: 60626........
# Processing zipcode 252: 46131........
# Could not find zipcode 253........
# Could not find zipcode 254........
# Could not find zipcode 255........
# Processing zipcode 256: 33430........
# Could not find zipcode 257........
# Processing zipcode 258: 20109........
# Could not find zipcode 259........
# Processing zipcode 260: 84660........
# Could not find zipcode 261........
# Processing zipcode 262: 48202........
# Could not find zipcode 263........
# Could not find zipcode 264........
# Processing zipcode 265: 60120........
# Could not find zipcode 266........
# Could not find zipcode 267........
# Processing zipcode 268: 70115........
# Could not find zipcode 269........
# Processing zipcode 270: 19124........
# Could not find zipcode 271........
# Processing zipcode 272: 36695........
# Could not find zipcode 273........
# Could not find zipcode 274........
# Processing zipcode 275: 28401........
# Could not find zipcode 276........
# Could not find zipcode 277........
# Could not find zipcode 278........
# Could not find zipcode 279........
# Could not find zipcode 280........
# Processing zipcode 281: 21215........
# Could not find zipcode 282........
# Could not find zipcode 283........
# Could not find zipcode 284........
# Could not find zipcode 285........
# Processing zipcode 286: 92408........
# Could not find zipcode 287........
# Processing zipcode 288: 60901........
# Processing zipcode 289: 80907........
# Processing zipcode 290: 95828........
# Could not find zipcode 291........
# Could not find zipcode 292........
# Could not find zipcode 293........
# Could not find zipcode 294........
# Could not find zipcode 295........
# Processing zipcode 296: 12550........
# Could not find zipcode 297........
# Could not find zipcode 298........
# Processing zipcode 299: 70117........
# Could not find zipcode 300........
# Could not find zipcode 301........
# Could not find zipcode 302........
# Processing zipcode 303: 35959........
# Could not find zipcode 304........
# Processing zipcode 305: 19138........
# Processing zipcode 306: 15909........
# Could not find zipcode 307........
# Could not find zipcode 308........
# Could not find zipcode 309........
# Processing zipcode 310: 48089........
# Could not find zipcode 311........
# Processing zipcode 312: 93307........
# Could not find zipcode 313........
# Processing zipcode 314: 29670........
# Processing zipcode 315: 70360........
# Processing zipcode 316: 76115........
# Processing zipcode 317: 47711........
# Processing zipcode 318: 27524........
# Could not find zipcode 319........
# Processing zipcode 320: 20032........
# Could not find zipcode 321........
# Processing zipcode 322: 37209........
# Processing zipcode 323: 60409........
# Processing zipcode 324: 70117........
# Processing zipcode 325: 46516........
# Processing zipcode 326: 33901........
# Processing zipcode 327: 30035........
# Could not find zipcode 328........
# Could not find zipcode 329........
# Processing zipcode 330: 61604........
# Could not find zipcode 331........
# Could not find zipcode 332........
# Processing zipcode 333: 21215........
# Processing zipcode 334: 97470........
# Could not find zipcode 335........
# Could not find zipcode 336........
# Could not find zipcode 337........
# Processing zipcode 338: 45417........
# Could not find zipcode 339........
# Could not find zipcode 340........
# Processing zipcode 341: 64108........
# Processing zipcode 342: 61832........
# Could not find zipcode 343........
# Processing zipcode 344: 71107........
# Could not find zipcode 345........
# Processing zipcode 346: 30093........
# Processing zipcode 347: 19124........
# Could not find zipcode 348........
# Could not find zipcode 349........
# Processing zipcode 350: 46208........
# Could not find zipcode 351........
# Could not find zipcode 352........
# Could not find zipcode 353........
# Processing zipcode 354: 34475........
# Processing zipcode 355: 71108........
# Processing zipcode 356: 14605........
# Could not find zipcode 357........
# Processing zipcode 358: 55411........
# Could not find zipcode 359........
# Could not find zipcode 360........
# Could not find zipcode 361........
# Could not find zipcode 362........
# Processing zipcode 363: 46403........
# Processing zipcode 364: 80202........
# Processing zipcode 365: 28217........
# Processing zipcode 366: 32114........
# Processing zipcode 367: 89122........
# Processing zipcode 368: 65201........
# Processing zipcode 369: 38109........
# Processing zipcode 370: 37620........
# Could not find zipcode 371........
# Processing zipcode 372: 11225........
# Processing zipcode 373: 93901........
# Processing zipcode 374: 60612........
# Could not find zipcode 375........
# Processing zipcode 376: 33407........
# Could not find zipcode 377........
# Processing zipcode 378: 95351........
# Could not find zipcode 379........
# Processing zipcode 380: 88203........
# Processing zipcode 381: 27704........
# Could not find zipcode 382........
# Could not find zipcode 383........
# Processing zipcode 384: 14611........
# Processing zipcode 385: 76133........
# Could not find zipcode 386........
# Could not find zipcode 387........
# Could not find zipcode 388........
# Could not find zipcode 389........
# Processing zipcode 390: 29115........
# Could not find zipcode 391........
# Could not find zipcode 392........
# Processing zipcode 393: 48205........
# Could not find zipcode 394........
# Processing zipcode 395: 28052........
# Processing zipcode 396: 72315........
# Processing zipcode 397: 77038........
# Could not find zipcode 398........
# Processing zipcode 399: 29204........
# Processing zipcode 400: 63112........
# Processing zipcode 401: 11231........
# Could not find zipcode 402........
# Processing zipcode 403: 21216........
# Could not find zipcode 404........
# Could not find zipcode 405........
# Could not find zipcode 406........
# Could not find zipcode 407........
# Could not find zipcode 408........
# Processing zipcode 409: 61102........
# Could not find zipcode 410........
# Could not find zipcode 411........
# Could not find zipcode 412........
# Could not find zipcode 413........
# Could not find zipcode 414........
# Could not find zipcode 415........
# Could not find zipcode 416........
# Could not find zipcode 417........
# Could not find zipcode 418........
# Could not find zipcode 419........
# Processing zipcode 420: 40211........
# Could not find zipcode 421........
# Could not find zipcode 422........
# Could not find zipcode 423........
# Processing zipcode 424: 97301........
# Processing zipcode 425: 70802........
# Could not find zipcode 426........
# Could not find zipcode 427........
# Processing zipcode 428: 37406........
# Could not find zipcode 429........
# Could not find zipcode 430........
# Could not find zipcode 431........
# Processing zipcode 432: 44108........
# Processing zipcode 433: 48228........
# Processing zipcode 434: 29059........
# Processing zipcode 435: 63147........
# Processing zipcode 436: 90650........
# Processing zipcode 437: 95204........
# Could not find zipcode 438........
# Could not find zipcode 439........
# Could not find zipcode 440........
# Could not find zipcode 441........
# Processing zipcode 442: 71103........
# Processing zipcode 443: 46803........
# Could not find zipcode 444........
# Processing zipcode 445: 20020........
# Could not find zipcode 446........
# Could not find zipcode 447........
# Could not find zipcode 448........
# Processing zipcode 449: 78201........
# Processing zipcode 450: 46222........
# Processing zipcode 451: 33054........
# Could not find zipcode 452........
# Processing zipcode 453: 62090........
# Processing zipcode 454: 19952........
# Could not find zipcode 455........
# Could not find zipcode 456........
# Processing zipcode 457: 10037........
# Could not find zipcode 458........
# Could not find zipcode 459........
# Processing zipcode 460: 40508........
# Processing zipcode 461: 28119........
# Could not find zipcode 462........
# Processing zipcode 463: 19104........
# Processing zipcode 464: 02895........
# Processing zipcode 465: 29401........
# Could not find zipcode 466........
# Processing zipcode 467: 11225........
# Processing zipcode 468: 08105........
# Could not find zipcode 469........
# Could not find zipcode 470........
# Could not find zipcode 471........
# Could not find zipcode 472........
# Could not find zipcode 473........
# Processing zipcode 474: 10468........
# Processing zipcode 475: 43211........
# Could not find zipcode 476........
# Processing zipcode 477: 06606........
# Processing zipcode 478: 77004........
# Could not find zipcode 479........
# Could not find zipcode 480........
# Could not find zipcode 481........
# Processing zipcode 482: 14217........
# Could not find zipcode 483........
# Could not find zipcode 484........
# Processing zipcode 485: 70116........
# Could not find zipcode 486........
# Processing zipcode 487: 44135........
# Processing zipcode 488: 20774........
# Processing zipcode 489: 06510........
# Could not find zipcode 490........
# Processing zipcode 491: 92102........
# Could not find zipcode 492........
# Could not find zipcode 493........
# Could not find zipcode 494........
# Processing zipcode 495: 70127........
# Processing zipcode 496: 62526........
# Processing zipcode 497: 02301........
# Could not find zipcode 498........
# Could not find zipcode 499........
# Processing zipcode 500: 63106........
# Could not find zipcode 501........
# Processing zipcode 502: 21205........
# Processing zipcode 503: 63140........
# Could not find zipcode 504........
# Could not find zipcode 505........
# Could not find zipcode 506........
# Processing zipcode 507: 14605........
# Could not find zipcode 508........
# Could not find zipcode 509........
# Could not find zipcode 510........
# Processing zipcode 511: 44111........
# Could not find zipcode 512........
# Could not find zipcode 513........
# Processing zipcode 514: 45225........
# Processing zipcode 515: 48228........
# Processing zipcode 516: 14215........
# Could not find zipcode 517........
# Could not find zipcode 518........
# Could not find zipcode 519........
# Processing zipcode 520: 45417........
# Could not find zipcode 521........
# Processing zipcode 522: 53216........
# Processing zipcode 523: 11226........
# Could not find zipcode 524........
# Could not find zipcode 525........
# Processing zipcode 526: 14624........
# Processing zipcode 527: 76541........
# Could not find zipcode 528........
# Processing zipcode 529: 36108........
# Processing zipcode 530: 17701........
# Could not find zipcode 531........
# Could not find zipcode 532........
# Could not find zipcode 533........
# Could not find zipcode 534........
# Processing zipcode 535: 30161........
# Could not find zipcode 536........
# Could not find zipcode 537........
# Processing zipcode 538: 46254........
# Processing zipcode 539: 49022........
# Could not find zipcode 540........
# Could not find zipcode 541........
# Processing zipcode 542: 32408........
# Processing zipcode 543: 79107........
# Could not find zipcode 544........
# Processing zipcode 545: 37040........
# Processing zipcode 546: 87112........
# Processing zipcode 547: 33605........
# Could not find zipcode 548........
# Processing zipcode 549: 75134........
# Processing zipcode 550: 07112........
# Processing zipcode 551: 85201........
# Processing zipcode 552: 95202........
# Could not find zipcode 553........
# Processing zipcode 554: 30311........
# Could not find zipcode 555........
# Processing zipcode 556: 39601........
# Processing zipcode 557: 31903........
# Could not find zipcode 558........
# Could not find zipcode 559........
# Processing zipcode 560: 63103........
# Could not find zipcode 561........
# Could not find zipcode 562........
# Processing zipcode 563: 48213........
# Processing zipcode 564: 21218........
# Could not find zipcode 565........
# Processing zipcode 566: 77033........
# Could not find zipcode 567........
# Processing zipcode 568: 76543........
# Processing zipcode 569: 30523........
# Processing zipcode 570: 29405........
# Processing zipcode 571: 95811........
# Processing zipcode 572: 72209........
# Could not find zipcode 573........
# Processing zipcode 574: 34654........
# Could not find zipcode 575........
# Processing zipcode 576: 30135........
# Processing zipcode 577: 74115........
# Could not find zipcode 578........
# Processing zipcode 579: 13204........
# Processing zipcode 580: 10031........
# Could not find zipcode 581........
# Could not find zipcode 582........
# Could not find zipcode 583........
# Could not find zipcode 584........
# Processing zipcode 585: 68111........
# Processing zipcode 586: 02130........
# Processing zipcode 587: 37042........
# Could not find zipcode 588........
# Processing zipcode 589: 61101........
# Could not find zipcode 590........
# Processing zipcode 591: 28348........
# Processing zipcode 592: 33810........
# Processing zipcode 593: 95111........
# Processing zipcode 594: 67218........
# Could not find zipcode 595........
# Processing zipcode 596: 02121........
# Processing zipcode 597: 37402........
# Could not find zipcode 598........
# Processing zipcode 599: 24017........
# Processing zipcode 600: 75253........
# Could not find zipcode 601........
# Could not find zipcode 602........
# Could not find zipcode 603........
# Processing zipcode 604: 77004........
# Processing zipcode 605: 44903........
# Processing zipcode 606: 06492........
# Processing zipcode 607: 31906........
# Could not find zipcode 608........
# Processing zipcode 609: 36360........
# Processing zipcode 610: 10550........
# Could not find zipcode 611........
# Processing zipcode 612: 27893........
# Could not find zipcode 613........
# Could not find zipcode 614........
# Could not find zipcode 615........
# Processing zipcode 616: 28206........
# Could not find zipcode 617........
# Could not find zipcode 618........
# Processing zipcode 619: 95841........
# Processing zipcode 620: 11237........
# Could not find zipcode 621........
# Processing zipcode 622: 21225........
# Could not find zipcode 623........
# Could not find zipcode 624........
# Processing zipcode 625: 93706........
# Processing zipcode 626: 87123........
# Could not find zipcode 627........
# Could not find zipcode 628........
# Could not find zipcode 629........
# Could not find zipcode 630........
# Could not find zipcode 631........
# Processing zipcode 632: 90744........
# Could not find zipcode 633........
# Processing zipcode 634: 70112........
# Could not find zipcode 635........
# Could not find zipcode 636........
# Could not find zipcode 637........
# Processing zipcode 638: 40211........
# Processing zipcode 639: 12206........
# Could not find zipcode 640........
# Processing zipcode 641: 33440........
# Could not find zipcode 642........
# Processing zipcode 643: 38024........
# Processing zipcode 644: 32209........
# Processing zipcode 645: 78218........
# Processing zipcode 646: 92105........
# Could not find zipcode 647........
# Processing zipcode 648: 95828........
# Could not find zipcode 649........
# Processing zipcode 650: 06604........
# Processing zipcode 651: 77012........
# Could not find zipcode 652........
# Processing zipcode 653: 98101........
# Could not find zipcode 654........
# Could not find zipcode 655........
# Could not find zipcode 656........
# Processing zipcode 657: 78217........
# Processing zipcode 658: 29582........
# Processing zipcode 659: 94612........
# Could not find zipcode 660........
# Processing zipcode 661: 19143........
# Processing zipcode 662: 60617........
# Processing zipcode 663: 07050........
# Processing zipcode 664: 72206........
# Processing zipcode 665: 38118........
# Could not find zipcode 666........
# Processing zipcode 667: 43607........
# Processing zipcode 668: 10002........
# Processing zipcode 669: 12550........
# Processing zipcode 670: 20743........
# Could not find zipcode 671........
# Processing zipcode 672: 45406........
# Processing zipcode 673: 90047........
# Processing zipcode 674: 92504........
# Processing zipcode 675: 39213........
# Could not find zipcode 676........
# Processing zipcode 677: 30233........
# Could not find zipcode 678........
# Processing zipcode 679: 24013........
# Could not find zipcode 680........
# Could not find zipcode 681........
# Processing zipcode 682: 94108........
# Could not find zipcode 683........
# Processing zipcode 684: 36617........
# Processing zipcode 685: 61108........
# Processing zipcode 686: 90016........
# Could not find zipcode 687........
# Could not find zipcode 688........
# Processing zipcode 689: 49508........
# Processing zipcode 690: 95815........
# Processing zipcode 691: 11209........
# Processing zipcode 692: 70119........
# Could not find zipcode 693........
# Processing zipcode 694: 78204........
# Could not find zipcode 695........
# Could not find zipcode 696........
# Processing zipcode 697: 94102........
# Could not find zipcode 698........
# Processing zipcode 699: 77338........
# Processing zipcode 700: 77005........
# Could not find zipcode 701........
# Could not find zipcode 702........
# Processing zipcode 703: 98233........
# Could not find zipcode 704........
# Processing zipcode 705: 15212........
# Processing zipcode 706: 24504........
# Processing zipcode 707: 33177........
# Processing zipcode 708: 32805........
# Processing zipcode 709: 46260........
# Processing zipcode 710: 20020........
# Could not find zipcode 711........
# Processing zipcode 712: 19139........
# Could not find zipcode 713........
# Processing zipcode 714: 46803........
# Processing zipcode 715: 46806........
# Processing zipcode 716: 70125........
# Processing zipcode 717: 64111........
# Processing zipcode 718: 48604........
# Could not find zipcode 719........
# Processing zipcode 720: 07306........
# Processing zipcode 721: 33142........
# Processing zipcode 722: 78617........
# Could not find zipcode 723........
# Could not find zipcode 724........
# Processing zipcode 725: 19604........
# Processing zipcode 726: 24012........
# Could not find zipcode 727........
# Could not find zipcode 728........
# Processing zipcode 729: 30308........
# Could not find zipcode 730........
# Processing zipcode 731: 08215........
# Processing zipcode 732: 79401........
# Processing zipcode 733: 10455........
# Could not find zipcode 734........
# Could not find zipcode 735........
# Could not find zipcode 736........
# Could not find zipcode 737........
# Could not find zipcode 738........
# Could not find zipcode 739........
# Processing zipcode 740: 06610........
# Processing zipcode 741: 06514........
# Processing zipcode 742: 98402........
# Could not find zipcode 743........
# Processing zipcode 744: 05676........
# Could not find zipcode 745........
# Processing zipcode 746: 23523........
# Processing zipcode 747: 55411........
# Could not find zipcode 748........
# Processing zipcode 749: 53216........
# Could not find zipcode 750........
# Processing zipcode 751: 64804........
# Could not find zipcode 752........
# Could not find zipcode 753........
# Could not find zipcode 754........
# Could not find zipcode 755........
# Processing zipcode 756: 95823........
# Processing zipcode 757: 32205........
# Processing zipcode 758: 87123........
# Could not find zipcode 759........
# Processing zipcode 760: 39183........
# Processing zipcode 761: 80002........
# Could not find zipcode 762........
# Could not find zipcode 763........
# Processing zipcode 764: 48341........
# Processing zipcode 765: 92570........
# Could not find zipcode 766........
# Processing zipcode 767: 30032........
# Could not find zipcode 768........
# Could not find zipcode 769........
# Could not find zipcode 770........
# Processing zipcode 771: 78701........
# Processing zipcode 772: 63108........
# Could not find zipcode 773........
# Could not find zipcode 774........
# Could not find zipcode 775........
# Processing zipcode 776: 14901........
# Could not find zipcode 777........
# Could not find zipcode 778........
# Processing zipcode 779: 33901........
# Processing zipcode 780: 45013........
# Processing zipcode 781: 29420........
# Processing zipcode 782: 45223........
# Could not find zipcode 783........
# Could not find zipcode 784........
# Could not find zipcode 785........
# Could not find zipcode 786........
# Could not find zipcode 787........
# Could not find zipcode 788........
# Processing zipcode 789: 77016........
# Could not find zipcode 790........
# Processing zipcode 791: 70815........
# Processing zipcode 792: 75217........
# Processing zipcode 793: 44103........
# Could not find zipcode 794........
# Processing zipcode 795: 93304........
# Processing zipcode 796: 37040........
# Processing zipcode 797: 98674........
# Processing zipcode 798: 77532........
# Processing zipcode 799: 94607........
# Processing zipcode 800: 44307........
# Processing zipcode 801: 31093........
# Processing zipcode 802: 63118........
# Could not find zipcode 803........
# Processing zipcode 804: 49203........
# Processing zipcode 805: 20019........
# Processing zipcode 806: 49085........
# Processing zipcode 807: 70806........
# Processing zipcode 808: 75202........
# Could not find zipcode 809........
# Could not find zipcode 810........
# Processing zipcode 811: 11233........
# Could not find zipcode 812........
# Could not find zipcode 813........
# Could not find zipcode 814........
# Processing zipcode 815: 77019........
# Could not find zipcode 816........
# Processing zipcode 817: 71201........
# Processing zipcode 818: 37406........
# Could not find zipcode 819........
# Could not find zipcode 820........
# Could not find zipcode 821........
# Could not find zipcode 822........
# Processing zipcode 823: 97071........
# Could not find zipcode 824........
# Processing zipcode 825: 28208........
# Processing zipcode 826: 30316........
# Processing zipcode 827: 77081........
# Could not find zipcode 828........
# Processing zipcode 829: 76102........
# Processing zipcode 830: 23523........
# Could not find zipcode 831........
# Could not find zipcode 832........
# Could not find zipcode 833........
# Processing zipcode 834: 20747........
# Could not find zipcode 835........
# Could not find zipcode 836........
# Could not find zipcode 837........
# Could not find zipcode 838........
# Processing zipcode 839: 40208........
# Processing zipcode 840: 24017........
# Could not find zipcode 841........
# Could not find zipcode 842........
# Could not find zipcode 843........
# Could not find zipcode 844........
# Processing zipcode 845: 94612........
# Could not find zipcode 846........
# Could not find zipcode 847........
# Could not find zipcode 848........
# Processing zipcode 849: 32806........
# Processing zipcode 850: 88201........
# Processing zipcode 851: 55088........
# Could not find zipcode 852........
# Could not find zipcode 853........
# Processing zipcode 854: 91402........
# Could not find zipcode 855........
# Could not find zipcode 856........
# Processing zipcode 857: 02135........
# Could not find zipcode 858........
# Processing zipcode 859: 55405........
# Could not find zipcode 860........
# Processing zipcode 861: 85051........
# Could not find zipcode 862........
# Processing zipcode 863: 80207........
# Could not find zipcode 864........
# Processing zipcode 865: 46815........
# Could not find zipcode 866........
# Processing zipcode 867: 95824........
# Could not find zipcode 868........
# Processing zipcode 869: 08618........
# Could not find zipcode 870........
# Processing zipcode 871: 77079........
# Processing zipcode 872: 07106........
# Processing zipcode 873: 70118........
# Could not find zipcode 874........
# Processing zipcode 875: 37203........
# Could not find zipcode 876........
# Could not find zipcode 877........
# Processing zipcode 878: 29470........
# Processing zipcode 879: 47711........
# Could not find zipcode 880........
# Could not find zipcode 881........
# Processing zipcode 882: 25387........
# Processing zipcode 883: 35234........
# Could not find zipcode 884........
# Could not find zipcode 885........
# Processing zipcode 886: 48205........
# Processing zipcode 887: 36104........
# Processing zipcode 888: 20817........
# Could not find zipcode 889........
# Could not find zipcode 890........
# Could not find zipcode 891........
# Processing zipcode 892: 37127........
# Could not find zipcode 893........
# Processing zipcode 894: 94608........
# Processing zipcode 895: 70814........
# Could not find zipcode 896........
# Could not find zipcode 897........
# Processing zipcode 898: 37209........
# Processing zipcode 899: 33147........
# Processing zipcode 900: 24558........
# Could not find zipcode 901........
# Could not find zipcode 902........
# Could not find zipcode 903........
# Could not find zipcode 904........
# Could not find zipcode 905........
# Processing zipcode 906: 66609........
# Could not find zipcode 907........
# Processing zipcode 908: 30802........
# Processing zipcode 909: 21206........
# Processing zipcode 910: 35031........
# Could not find zipcode 911........
# Could not find zipcode 912........
# Could not find zipcode 913........
# Processing zipcode 914: 19140........
# Processing zipcode 915: 29669........
# Could not find zipcode 916........
# Processing zipcode 917: 48211........
# Processing zipcode 918: 32805........
# Could not find zipcode 919........
# Could not find zipcode 920........
# Could not find zipcode 921........
# Could not find zipcode 922........
# Could not find zipcode 923........
# Processing zipcode 924: 87106........
# Could not find zipcode 925........
# Could not find zipcode 926........
# Could not find zipcode 927........
# Processing zipcode 928: 80230........
# Could not find zipcode 929........
# Could not find zipcode 930........
# Could not find zipcode 931........
# Could not find zipcode 932........
# Could not find zipcode 933........
# Processing zipcode 934: 97233........
# Could not find zipcode 935........
# Processing zipcode 936: 48206........
# Could not find zipcode 937........
# Processing zipcode 938: 15221........
# Could not find zipcode 939........
# Processing zipcode 940: 70501........
# Could not find zipcode 941........
# Processing zipcode 942: 02150........
# Processing zipcode 943: 30075........
# Could not find zipcode 944........
# Processing zipcode 945: 67202........
# Processing zipcode 946: 43201........
# Processing zipcode 947: 48204........
# Could not find zipcode 948........
# Could not find zipcode 949........
# Processing zipcode 950: 98528........
# Processing zipcode 951: 67062........
# Processing zipcode 952: 85304........
# Processing zipcode 953: 32114........
# Processing zipcode 954: 77021........
# Processing zipcode 955: 63042........
# Processing zipcode 956: 33618........
# Processing zipcode 957: 49009........
# Processing zipcode 958: 35022........
# Processing zipcode 959: 32805........
# Processing zipcode 960: 38852........
# Processing zipcode 961: 64444........
# Processing zipcode 962: 94590........
# Processing zipcode 963: 77017........
# Could not find zipcode 964........
# Processing zipcode 965: 70072........
# Could not find zipcode 966........
# Processing zipcode 967: 32819........
# Processing zipcode 968: 14608........
# Could not find zipcode 969........
# Processing zipcode 970: 90061........
# Could not find zipcode 971........
# Processing zipcode 972: 33604........
# Processing zipcode 973: 20020........
# Could not find zipcode 974........
# Processing zipcode 975: 23323........
# Could not find zipcode 976........
# Processing zipcode 977: 92570........
# Processing zipcode 978: 90003........
# Could not find zipcode 979........
# Processing zipcode 980: 19805........
# Could not find zipcode 981........
# Could not find zipcode 982........
# Processing zipcode 983: 38128........
# Processing zipcode 984: 33801........
# Could not find zipcode 985........
# Processing zipcode 986: 60645........
# Processing zipcode 987: 07740........
# Processing zipcode 988: 89110........
# Could not find zipcode 989........
# Could not find zipcode 990........
# Processing zipcode 991: 36081........
# Could not find zipcode 992........
# Could not find zipcode 993........
# Could not find zipcode 994........
# Processing zipcode 995: 19142........
# Could not find zipcode 996........
# Processing zipcode 997: 91331........
# Could not find zipcode 998........
# Could not find zipcode 999........
# Processing zipcode 1000: 75040........
# Could not find zipcode 1001........
# Processing zipcode 1002: 60640........
# Processing zipcode 1003: 15206........
# Processing zipcode 1004: 38103........
# Processing zipcode 1005: 48202........
# Could not find zipcode 1006........
# Processing zipcode 1007: 39601........
# Processing zipcode 1008: 44120........
# Processing zipcode 1009: 55412........
# Processing zipcode 1010: 70560........
# Processing zipcode 1011: 31901........
# Processing zipcode 1012: 96021........
# Processing zipcode 1013: 94803........
# Processing zipcode 1014: 46403........
# Could not find zipcode 1015........
# Could not find zipcode 1016........
# Processing zipcode 1017: 75215........
# Could not find zipcode 1018........
# Processing zipcode 1019: 28303........
# Could not find zipcode 1020........
# Could not find zipcode 1021........
# Processing zipcode 1022: 78161........
# Could not find zipcode 1023........
# Processing zipcode 1024: 44507........
# Processing zipcode 1025: 90401........
# Could not find zipcode 1026........
# Could not find zipcode 1027........
# Processing zipcode 1028: 14215........
# Could not find zipcode 1029........
# Processing zipcode 1030: 78751........
# Processing zipcode 1031: 43604........
# Could not find zipcode 1032........
# Processing zipcode 1033: 40210........
# Could not find zipcode 1034........
# Could not find zipcode 1035........
# Could not find zipcode 1036........
# Processing zipcode 1037: 36863........
# Processing zipcode 1038: 32218........
# Processing zipcode 1039: 37203........
# Could not find zipcode 1040........
# Could not find zipcode 1041........
# Processing zipcode 1042: 21040........
# Processing zipcode 1043: 11226........
# Could not find zipcode 1044........
# Processing zipcode 1045: 77081........
# Could not find zipcode 1046........
# Could not find zipcode 1047........
# Processing zipcode 1048: 45659........
# Could not find zipcode 1049........
# Processing zipcode 1050: 77021........
# Could not find zipcode 1051........
# Could not find zipcode 1052........
# Could not find zipcode 1053........
# Could not find zipcode 1054........
# Processing zipcode 1055: 66044........
# Processing zipcode 1056: 89119........
# Processing zipcode 1057: 38106........
# Processing zipcode 1058: 70119........
# Processing zipcode 1059: 19144........
# Processing zipcode 1060: 38108........
# Processing zipcode 1061: 21213........
# Could not find zipcode 1062........
# Processing zipcode 1063: 37013........
# Processing zipcode 1064: 13210........
# Processing zipcode 1065: 08330........
# Processing zipcode 1066: 93309........
# Could not find zipcode 1067........
# Processing zipcode 1068: 06112........
# Processing zipcode 1069: 46404........
# Could not find zipcode 1070........
# Processing zipcode 1071: 23803........
# Processing zipcode 1072: 29201........
# Processing zipcode 1073: 38107........
# Processing zipcode 1074: 99030........
# Could not find zipcode 1075........
# Could not find zipcode 1076........
# Processing zipcode 1077: 70116........
# Processing zipcode 1078: 75023........
# Could not find zipcode 1079........
# Could not find zipcode 1080........
# Processing zipcode 1081: 60104........
# Could not find zipcode 1082........
# Processing zipcode 1083: 40291........
# Could not find zipcode 1084........
# Processing zipcode 1085: 88101........
# Processing zipcode 1086: 95832........
# Processing zipcode 1087: 47713........
# Processing zipcode 1088: 32603........
# Processing zipcode 1089: 63137........
# Could not find zipcode 1090........
# Could not find zipcode 1091........
# Processing zipcode 1092: 27891........
# Could not find zipcode 1093........
# Could not find zipcode 1094........
# Processing zipcode 1095: 38105........
# Could not find zipcode 1096........
# Could not find zipcode 1097........
# Processing zipcode 1098: 44106........
# Could not find zipcode 1099........
# Could not find zipcode 1100........
# Could not find zipcode 1101........
# Processing zipcode 1102: 95820........
# Processing zipcode 1103: 23437........
# Processing zipcode 1104: 63138........
# Could not find zipcode 1105........
# Could not find zipcode 1106........
# Could not find zipcode 1107........
# Processing zipcode 1108: 94603........
# Processing zipcode 1109: 08701........
# Processing zipcode 1110: 29810........
# Processing zipcode 1111: 32304........
# Could not find zipcode 1112........
# Processing zipcode 1113: 20018........
# Could not find zipcode 1114........
# Could not find zipcode 1115........
# Processing zipcode 1116: 98948........
# Could not find zipcode 1117........
# Could not find zipcode 1118........
# Processing zipcode 1119: 23502........
# Processing zipcode 1120: 79936........
# Processing zipcode 1121: 14215........
# Processing zipcode 1122: 28144........
# Could not find zipcode 1123........
# Could not find zipcode 1124........
# Processing zipcode 1125: 27260........
# Processing zipcode 1126: 32209........
# Could not find zipcode 1127........
# Processing zipcode 1128: 70807........
# Processing zipcode 1129: 45202........
# Processing zipcode 1130: 23223........
# Could not find zipcode 1131........
# Could not find zipcode 1132........
# Could not find zipcode 1133........
# Could not find zipcode 1134........
# Could not find zipcode 1135........
# Could not find zipcode 1136........
# Processing zipcode 1137: 23868........
# Processing zipcode 1138: 62024........
# Processing zipcode 1139: 45251........
# Could not find zipcode 1140........
# Could not find zipcode 1141........
# Could not find zipcode 1142........
# Processing zipcode 1143: 04950........
# Could not find zipcode 1144........
# Processing zipcode 1145: 23669........
# Processing zipcode 1146: 27601........
# Could not find zipcode 1147........
# Processing zipcode 1148: 48341........
# Could not find zipcode 1149........
# Could not find zipcode 1150........
# Could not find zipcode 1151........
# Could not find zipcode 1152........
# Could not find zipcode 1153........
# Processing zipcode 1154: 72201........
# Processing zipcode 1155: 10457........
# Could not find zipcode 1156........
# Processing zipcode 1157: 20019........
# Processing zipcode 1158: 63115........
# Could not find zipcode 1159........
# Could not find zipcode 1160........
# Could not find zipcode 1161........
# Processing zipcode 1162: 30310........
# Could not find zipcode 1163........
# Processing zipcode 1164: 20020........
# Could not find zipcode 1165........
# Processing zipcode 1166: 29575........
# Could not find zipcode 1167........
# Processing zipcode 1168: 43229........
# Processing zipcode 1169: 23227........
# Processing zipcode 1170: 87539........
# Processing zipcode 1171: 22301........
# Could not find zipcode 1172........
# Processing zipcode 1173: 94107........
# Processing zipcode 1174: 21216........
# Processing zipcode 1175: 21218........
# Could not find zipcode 1176........
# Could not find zipcode 1177........
# Could not find zipcode 1178........
# Processing zipcode 1179: 77090........
# Processing zipcode 1180: 38104........
# Could not find zipcode 1181........
# Processing zipcode 1182: 70122........
# Processing zipcode 1183: 84093........
# Processing zipcode 1184: 32807........
# Processing zipcode 1185: 63113........
# Processing zipcode 1186: 70119........
# Could not find zipcode 1187........
# Processing zipcode 1188: 78041........
# Could not find zipcode 1189........
# Processing zipcode 1190: 45044........
# Could not find zipcode 1191........
# Processing zipcode 1192: 36869........
# Processing zipcode 1193: 07505........
# Could not find zipcode 1194........
# Processing zipcode 1195: 10014........
# Processing zipcode 1196: 20001........
# Processing zipcode 1197: 39629........
# Could not find zipcode 1198........
# Processing zipcode 1199: 50310........
# Processing zipcode 1200: 85213........
# Could not find zipcode 1201........
# Processing zipcode 1202: 29475........
# Processing zipcode 1203: 72401........
# Processing zipcode 1204: 60419........
# Could not find zipcode 1205........
# Processing zipcode 1206: 76116........
# Processing zipcode 1207: 08611........
# Could not find zipcode 1208........
# Could not find zipcode 1209........
# Processing zipcode 1210: 48503........
# Processing zipcode 1211: 32209........
# Processing zipcode 1212: 75223........
# Processing zipcode 1213: 92122........
# Processing zipcode 1214: 66614........
# Could not find zipcode 1215........
# Could not find zipcode 1216........
# Could not find zipcode 1217........
# Processing zipcode 1218: 95820........
# Processing zipcode 1219: 90605........
# Processing zipcode 1220: 20874........
# Could not find zipcode 1221........
# Processing zipcode 1222: 23451........
# Processing zipcode 1223: 19013........
# Could not find zipcode 1224........
# Could not find zipcode 1225........
# Processing zipcode 1226: 32905........
# Could not find zipcode 1227........
# Processing zipcode 1228: 94590........
# Processing zipcode 1229: 27909........
# Processing zipcode 1230: 43211........
# Processing zipcode 1231: 61071........
# Processing zipcode 1232: 19120........
# Could not find zipcode 1233........
# Processing zipcode 1234: 35215........
# Processing zipcode 1235: 60426........
# Could not find zipcode 1236........
# Processing zipcode 1237: 30314........
# Processing zipcode 1238: 78224........
# Processing zipcode 1239: 46818........
# Processing zipcode 1240: 28601........
# Processing zipcode 1241: 77021........
# Processing zipcode 1242: 55109........
# Could not find zipcode 1243........
# Processing zipcode 1244: 70601........
# Could not find zipcode 1245........
# Processing zipcode 1246: 79412........
# Could not find zipcode 1247........
# Processing zipcode 1248: 50310........
# Processing zipcode 1249: 94565........
# Processing zipcode 1250: 33606........
# Could not find zipcode 1251........
# Processing zipcode 1252: 60649........
# Processing zipcode 1253: 32771........
# Could not find zipcode 1254........
# Processing zipcode 1255: 77032........
# Processing zipcode 1256: 45226........
# Could not find zipcode 1257........
# Processing zipcode 1258: 48204........
# Could not find zipcode 1259........
# Could not find zipcode 1260........
# Processing zipcode 1261: 63115........
# Processing zipcode 1262: 54474........
# Processing zipcode 1263: 40203........
# Processing zipcode 1264: 48227........
# Processing zipcode 1265: 70001........
# Processing zipcode 1266: 60615........
# Could not find zipcode 1267........
# Could not find zipcode 1268........
# Processing zipcode 1269: 31904........
# Could not find zipcode 1270........
# Processing zipcode 1271: 95817........
# Processing zipcode 1272: 19119........
# Processing zipcode 1273: 92503........
# Processing zipcode 1274: 45223........
# Could not find zipcode 1275........
# Processing zipcode 1276: 46404........
# Processing zipcode 1277: 44484........
# Processing zipcode 1278: 32209........
# Processing zipcode 1279: 14611........
# Processing zipcode 1280: 44111........
# Could not find zipcode 1281........
# Processing zipcode 1282: 44108........
# Could not find zipcode 1283........
# Could not find zipcode 1284........
# Processing zipcode 1285: 46616........
# Processing zipcode 1286: 93901........
# Processing zipcode 1287: 60632........
# Processing zipcode 1288: 63830........
# Processing zipcode 1289: 12550........
# Could not find zipcode 1290........
# Could not find zipcode 1291........
# Could not find zipcode 1292........
# Could not find zipcode 1293........
# Processing zipcode 1294: 39209........
# Processing zipcode 1295: 44112........
# Processing zipcode 1296: 29203........
# Processing zipcode 1297: 72210........
# Could not find zipcode 1298........
# Processing zipcode 1299: 38117........
# Could not find zipcode 1300........
# Could not find zipcode 1301........
# Processing zipcode 1302: 71108........
# Could not find zipcode 1303........
# Processing zipcode 1304: 38012........
# Processing zipcode 1305: 31707........
# Could not find zipcode 1306........
# Could not find zipcode 1307........
# Could not find zipcode 1308........
# Processing zipcode 1309: 30331........
# Processing zipcode 1310: 30236........
# Processing zipcode 1311: 33435........
# Processing zipcode 1312: 38109........
# Could not find zipcode 1313........
# Could not find zipcode 1314........
# Processing zipcode 1315: 77033........
# Processing zipcode 1316: 33142........
# Could not find zipcode 1317........
# Processing zipcode 1318: 39652........
# Processing zipcode 1319: 64129........
# Processing zipcode 1320: 93905........
# Could not find zipcode 1321........
# Could not find zipcode 1322........
# Processing zipcode 1323: 48506........
# Could not find zipcode 1324........
# Processing zipcode 1325: 33315........
# Processing zipcode 1326: 92337........
# Processing zipcode 1327: 75002........
# Could not find zipcode 1328........
# Processing zipcode 1329: 75243........
# Could not find zipcode 1330........
# ---------------
# Finished Processing
# ---------------

# %%
# Print preview to verify
shooting_data.head(25)
# Out:
#    Incident Date         State  City Or County  \
# 0     2014-12-29     Louisiana     New Orleans
# 1     2014-12-27    California     Los Angeles
# 2     2014-12-27    California      Sacramento
# 3     2014-12-26      Illinois  East St. Louis
# 4     2014-12-24      Missouri     Saint Louis
# 5     2014-12-23      Kentucky      Winchester
# 6     2014-12-22      Michigan         Detroit
# 7     2014-12-22      New York         Webster
# 8     2014-12-22      Illinois         Chicago
# 9     2014-12-21       Florida        Sarasota
# 10    2014-12-21   Mississippi      Waynesboro
# 11    2014-12-21      Illinois    Calumet City
# 12    2014-12-20      Illinois        Rockford
# 13    2014-12-16    New Jersey       Elizabeth
# 14    2014-12-15  Pennsylvania        Lansdale
# 15    2014-12-14       Florida           Miami
# 16    2014-12-13       Florida           Tampa
# 17    2014-12-12        Oregon        Portland
# 18    2014-12-07       Indiana      South Bend
# 19    2014-12-02      Missouri     Saint Louis
# 20    2014-12-02      Virginia    Newport News
# 21    2014-11-30      New York        Brooklyn
# 22    2014-11-30     Tennessee     Chattanooga
# 23    2014-11-29    New Jersey          Newark
# 24    2014-11-29       Georgia         Atlanta
#
#                                 Address  # Killed  # Injured  Operations  ST  \
# 0                   Poydras and Bolivar         0          4         NaN  LA
# 1   8800 block of South Figueroa Street         1          3         NaN  CA
# 2              4000 block of May Street         0          4         NaN  CA
# 3           2500 block of Summit Avenue         1          3         NaN  IL
# 4                         18th and Pine         1          3         NaN  MO
# 5                      260 Oxford Drive         1          3         NaN  KY
# 6                 Charlevoix and Philip         1          3         NaN  MI
# 7                         191 Lake Road         4          2         NaN  NY
# 8      5700 block of South Green Street         0          5         NaN  IL
# 9                4034 N Washington Blvd         2          2         NaN  FL
# 10                       Central Avenue         1          4         NaN  MS
# 11                 600 block of Escanba         1          8         NaN  IL
# 12        3200 block of Montrose Avenue         4          0         NaN  IL
# 13                          Anna Street         0          4         NaN  NJ
# 14             100 block of West 5th St         7          0         NaN  PA
# 15            1311 Northwest 2nd Avenue         1          4         NaN  FL
# 16                  810 E. Skagway Ave.         0          5         NaN  FL
# 17        717 North Killingsworth Court         0          4         NaN  OR
# 18        16000 block of Roosevelt Road         0          4         NaN  IN
# 19        6000 block of Virginia Avenue         1          5         NaN  MO
# 20                  6128 Jefferson Ave          0          5         NaN  VA
# 21                    375 Remsen Avenue         0          4         NaN  NY
# 22               2412 East 13th Street          0          5         NaN  TN
# 23                     348 S Orange Ave         1          3         NaN  NJ
# 24        1600 block of Richmond Avenue         3          2         NaN  GA
#
#    Zipcode
# 0      NaN
# 1      NaN
# 2    95838
# 3    62205
# 4    63103
# 5    40391
# 6      NaN
# 7      NaN
# 8      NaN
# 9    34234
# 10     NaN
# 11   60409
# 12   61101
# 13     NaN
# 14     NaN
# 15   33136
# 16   33604
# 17   97217
# 18     NaN
# 19   63111
# 20   23605
# 21   11212
# 22   37404
# 23   07103
# 24   30315

# %%
# Find how many unidentifiable zipcodes
len(problems)
# Out:
# 625

# %%
# Run through address information with Google geocode to try to find any of the remaining unidentifiable zipcodes
params = {"key": gkey}

for n in problems:
    
    try:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json"

        address = shooting_data['Address'][n]
        city = shooting_data['City Or County'][n]
        state = shooting_data['State'][n]

        # update address key value
        params['address'] = f"{address} {city},{state}"

        # make request
        address = requests.get(base_url, params=params)

        # convert to json
        address = address.json()
        address = address["results"][0]["formatted_address"]
        zipcode = address.split(', ')[2].split(' ')[1]

        shooting_data.loc[n, "Zipcode"] = zipcode
        print(f"Processing zipcode {n}: {zipcode}........")
        
    except:
        shooting_data.loc[n, "Zipcode"] = "NaN"
        print(f"Can't find {n} zipcode")
        
print(f"---------------\nFinished Processing\n---------------")
# Out:
# Processing zipcode 0: 70113........
# Processing zipcode 1: 90003........
# Can't find 6 zipcode
# Processing zipcode 7: 14580........
# Processing zipcode 8: 60621........
# Processing zipcode 10: 39367........
# Processing zipcode 13: 07201........
# Processing zipcode 14: 19446........
# Processing zipcode 18: 46614........
# Processing zipcode 26: 78626........
# Processing zipcode 27: 94103........
# Can't find 28 zipcode
# Processing zipcode 29: 80204........
# Processing zipcode 31: 57262........
# Processing zipcode 32: 45505........
# Processing zipcode 34: 60624........
# Can't find 35 zipcode
# Processing zipcode 39: 33142........
# Processing zipcode 41: 90222........
# Processing zipcode 42: 90222........
# Processing zipcode 44: 38128........
# Processing zipcode 47: 11101........
# Can't find 49 zipcode
# Processing zipcode 50: 48224........
# Processing zipcode 53: 95210........
# Processing zipcode 54: 30315........
# Can't find 56 zipcode
# Processing zipcode 57: 12203........
# Processing zipcode 59: 48234........
# Processing zipcode 63: 93705........
# Processing zipcode 65: 33150........
# Can't find 67 zipcode
# Processing zipcode 70: 11369........
# Can't find 71 zipcode
# Processing zipcode 72: 70126........
# Processing zipcode 73: 78418........
# Processing zipcode 79: 90011........
# Processing zipcode 80: 92410........
# Processing zipcode 81: 39213........
# Processing zipcode 82: 94550........
# Processing zipcode 85: 60620........
# Processing zipcode 89: 70582........
# Processing zipcode 90: 11434........
# Processing zipcode 91: 02111........
# Processing zipcode 92: 94303........
# Processing zipcode 93: 89106........
# Processing zipcode 94: 07063........
# Processing zipcode 97: 37040........
# Can't find 98 zipcode
# Can't find 99 zipcode
# Processing zipcode 100: 14215........
# Can't find 102 zipcode
# Processing zipcode 104: 20024........
# Processing zipcode 106: 53210........
# Processing zipcode 107: 20002........
# Processing zipcode 110: 30314........
# Processing zipcode 111: 77338........
# Processing zipcode 113: 22724........
# Processing zipcode 114: 38401........
# Can't find 116 zipcode
# Processing zipcode 117: 15201........
# Processing zipcode 118: 19146........
# Processing zipcode 120: 19120........
# Processing zipcode 121: 63107........
# Can't find 122 zipcode
# Processing zipcode 124: 31791........
# Processing zipcode 130: 89130........
# Can't find 132 zipcode
# Processing zipcode 133: 98178........
# Processing zipcode 140: 41553........
# Processing zipcode 142: 33147........
# Processing zipcode 148: 46220........
# Processing zipcode 151: 19013........
# Processing zipcode 152: 40511........
# Processing zipcode 155: 90029........
# Processing zipcode 157: 10037........
# Processing zipcode 158: 92154........
# Processing zipcode 159: 53206........
# Processing zipcode 160: 48238........
# Processing zipcode 161: 01851........
# Processing zipcode 162: 33147........
# Processing zipcode 163: 95492........
# Processing zipcode 164: 20009........
# Processing zipcode 169: 90003........
# Processing zipcode 170: 07501........
# Can't find 172 zipcode
# Can't find 175 zipcode
# Processing zipcode 177: 60644........
# Processing zipcode 179: 92410........
# Can't find 181 zipcode
# Processing zipcode 182: 29582........
# Processing zipcode 183: 93117........
# Processing zipcode 188: 92236........
# Processing zipcode 190: 30311........
# Can't find 192 zipcode
# Can't find 195 zipcode
# Processing zipcode 196: 30032........
# Processing zipcode 202: 12180........
# Processing zipcode 206: 33605........
# Processing zipcode 210: 47374........
# Processing zipcode 211: 37419........
# Processing zipcode 213: 70119........
# Processing zipcode 215: 73107........
# Processing zipcode 217: 85035........
# Processing zipcode 218: 94533........
# Processing zipcode 219: 76544........
# Can't find 220 zipcode
# Processing zipcode 224: 94102........
# Can't find 226 zipcode
# Processing zipcode 227: 30830........
# Processing zipcode 228: 11211........
# Processing zipcode 230: 78745........
# Processing zipcode 233: 29669........
# Can't find 234 zipcode
# Processing zipcode 236: 24340........
# Processing zipcode 237: 90744........
# Processing zipcode 238: 46237........
# Processing zipcode 241: 92109........
# Processing zipcode 243: 75215........
# Processing zipcode 244: 46816........
# Processing zipcode 245: 89109........
# Processing zipcode 247: 94601........
# Can't find 248 zipcode
# Can't find 249 zipcode
# Processing zipcode 253: 27804........
# Processing zipcode 254: 98104........
# Processing zipcode 255: 60609........
# Can't find 257 zipcode
# Processing zipcode 259: 73401........
# Processing zipcode 261: 90045........
# Processing zipcode 263: 39209........
# Can't find 264 zipcode
# Processing zipcode 266: 11434........
# Processing zipcode 267: 23523........
# Can't find 269 zipcode
# Processing zipcode 271: 32206........
# Processing zipcode 273: 94578........
# Processing zipcode 274: 33162........
# Processing zipcode 276: 33170........
# Processing zipcode 277: 90007........
# Processing zipcode 278: 92647........
# Processing zipcode 279: 31401........
# Processing zipcode 280: 62059........
# Processing zipcode 282: 15210........
# Processing zipcode 283: 45225........
# Processing zipcode 284: 70394........
# Processing zipcode 285: 68164........
# Processing zipcode 287: 31401........
# Processing zipcode 291: 29527........
# Processing zipcode 292: 43204........
# Can't find 293 zipcode
# Processing zipcode 294: 78521........
# Processing zipcode 295: 98122........
# Processing zipcode 297: 29405........
# Processing zipcode 298: 60624........
# Processing zipcode 300: 21217........
# Processing zipcode 301: 15229........
# Processing zipcode 302: 93706........
# Can't find 304 zipcode
# Processing zipcode 307: 32218........
# Processing zipcode 308: 46201........
# Processing zipcode 309: 50313........
# Processing zipcode 311: 80223........
# Processing zipcode 313: 32209........
# Processing zipcode 319: 85041........
# Processing zipcode 321: 29003........
# Processing zipcode 328: 38115........
# Processing zipcode 329: 28208........
# Processing zipcode 331: 86001........
# Processing zipcode 332: 21223........
# Processing zipcode 335: 45207........
# Processing zipcode 336: 60609........
# Processing zipcode 337: 60609........
# Processing zipcode 339: 30222........
# Processing zipcode 340: 60609........
# Processing zipcode 343: 60609........
# Processing zipcode 345: 33916........
# Processing zipcode 348: 60621........
# Processing zipcode 349: 74115........
# Processing zipcode 351: 57342........
# Processing zipcode 352: 49224........
# Processing zipcode 353: 07103........
# Processing zipcode 357: 55403........
# Processing zipcode 359: 28206........
# Processing zipcode 360: 55331........
# Can't find 361 zipcode
# Can't find 362 zipcode
# Processing zipcode 371: 75706........
# Processing zipcode 375: 55429........
# Processing zipcode 377: 70125........
# Can't find 379 zipcode
# Processing zipcode 382: 45227........
# Can't find 383 zipcode
# Processing zipcode 386: 60651........
# Can't find 387 zipcode
# Processing zipcode 388: 15205........
# Processing zipcode 389: 90062........
# Processing zipcode 391: 90813........
# Processing zipcode 392: 39074........
# Processing zipcode 394: 64111........
# Processing zipcode 398: 05641........
# Processing zipcode 402: 11208........
# Processing zipcode 404: 60651........
# Can't find 405 zipcode
# Processing zipcode 406: 60636........
# Processing zipcode 407: 32807........
# Can't find 408 zipcode
# Processing zipcode 410: 64124........
# Processing zipcode 411: 70126........
# Processing zipcode 412: 23860........
# Processing zipcode 413: 16508........
# Processing zipcode 414: 70503........
# Processing zipcode 415: 63115........
# Processing zipcode 416: 30024........
# Processing zipcode 417: 33056........
# Processing zipcode 418: 10451........
# Processing zipcode 419: 23434........
# Processing zipcode 421: 27801........
# Processing zipcode 422: 92113........
# Can't find 423 zipcode
# Processing zipcode 426: 60624........
# Processing zipcode 427: 45211........
# Processing zipcode 429: 75212........
# Processing zipcode 430: 30318........
# Processing zipcode 431: 21215........
# Processing zipcode 438: 60305........
# Processing zipcode 439: 07306........
# Processing zipcode 440: 44128........
# Processing zipcode 441: 21223........
# Processing zipcode 444: 07018........
# Processing zipcode 446: 40211........
# Processing zipcode 447: 01201........
# Processing zipcode 448: 13204........
# Processing zipcode 452: 48205........
# Processing zipcode 455: 02780........
# Processing zipcode 456: 48213........
# Processing zipcode 458: 19134........
# Processing zipcode 459: 15221........
# Processing zipcode 462: 48206........
# Processing zipcode 466: 33169........
# Processing zipcode 469: 74115........
# Processing zipcode 470: 63106........
# Processing zipcode 471: 30214........
# Processing zipcode 472: 73149........
# Processing zipcode 473: 31061........
# Processing zipcode 476: 33142........
# Processing zipcode 479: 90044........
# Processing zipcode 480: 63113........
# Processing zipcode 481: 59722........
# Processing zipcode 483: 60644........
# Processing zipcode 484: 52802........
# Processing zipcode 486: 11798........
# Processing zipcode 490: 30013........
# Processing zipcode 492: 68127........
# Processing zipcode 493: 60636........
# Processing zipcode 494: 19013........
# Processing zipcode 498: 48507........
# Can't find 499 zipcode
# Processing zipcode 501: 93725........
# Processing zipcode 504: 33147........
# Processing zipcode 505: 76711........
# Processing zipcode 506: 53216........
# Processing zipcode 508: 21213........
# Processing zipcode 509: 20743........
# Processing zipcode 510: 85757........
# Processing zipcode 512: 07305........
# Processing zipcode 513: 07103........
# Processing zipcode 517: 46613........
# Processing zipcode 518: 77004........
# Can't find 519 zipcode
# Can't find 521 zipcode
# Can't find 524 zipcode
# Can't find 525 zipcode
# Processing zipcode 528: 23220........
# Can't find 531 zipcode
# Processing zipcode 532: 28208........
# Processing zipcode 533: 07501........
# Processing zipcode 534: 85032........
# Processing zipcode 536: 15219........
# Processing zipcode 537: 40211........
# Processing zipcode 540: 32114........
# Processing zipcode 541: 21217........
# Processing zipcode 544: 46208........
# Processing zipcode 548: 73104........
# Processing zipcode 553: 90220........
# Processing zipcode 555: 92236........
# Processing zipcode 558: 60628........
# Can't find 559 zipcode
# Processing zipcode 561: 92408........
# Processing zipcode 562: 32819........
# Processing zipcode 565: 65464........
# Processing zipcode 567: 32114........
# Processing zipcode 573: 90813........
# Processing zipcode 575: 38034........
# Can't find 578 zipcode
# Processing zipcode 581: 30240........
# Processing zipcode 582: 30088........
# Processing zipcode 583: 95206........
# Processing zipcode 584: 11413........
# Processing zipcode 588: 78202........
# Processing zipcode 590: 23321........
# Processing zipcode 595: 94102........
# Processing zipcode 598: 33147........
# Processing zipcode 601: 31405........
# Processing zipcode 602: 38119........
# Processing zipcode 603: 31637........
# Processing zipcode 608: 60619........
# Processing zipcode 611: 27025........
# Processing zipcode 613: 35234........
# Processing zipcode 614: 60644........
# Processing zipcode 615: 60628........
# Processing zipcode 617: 60612........
# Processing zipcode 618: 60632........
# Processing zipcode 621: 32808........
# Processing zipcode 623: 27801........
# Can't find 624 zipcode
# Processing zipcode 627: 90047........
# Processing zipcode 628: 07003........
# Can't find 629 zipcode
# Processing zipcode 630: 21216........
# Processing zipcode 631: 78572........
# Processing zipcode 633: 90731........
# Processing zipcode 635: 64132........
# Processing zipcode 636: 60617........
# Processing zipcode 637: 70113........
# Can't find 640 zipcode
# Processing zipcode 642: 60639........
# Processing zipcode 647: 32811........
# Can't find 649 zipcode
# Processing zipcode 652: 77085........
# Processing zipcode 654: 60624........
# Processing zipcode 655: 38116........
# Processing zipcode 656: 33312........
# Processing zipcode 660: 60640........
# Processing zipcode 666: 71106........
# Processing zipcode 671: 78238........
# Processing zipcode 676: 33056........
# Processing zipcode 678: 45405........
# Can't find 680 zipcode
# Processing zipcode 681: 94605........
# Processing zipcode 683: 60636........
# Processing zipcode 687: 60624........
# Processing zipcode 688: 60612........
# Processing zipcode 693: 55401........
# Processing zipcode 695: 60958........
# Processing zipcode 696: 93702........
# Processing zipcode 698: 27105........
# Processing zipcode 701: 61820........
# Processing zipcode 702: 21202........
# Processing zipcode 704: 19134........
# Processing zipcode 711: 90004........
# Processing zipcode 713: 77396........
# Can't find 719 zipcode
# Processing zipcode 723: 71913........
# Processing zipcode 724: 60612........
# Processing zipcode 727: 28405........
# Can't find 728 zipcode
# Processing zipcode 730: 60636........
# Processing zipcode 734: 63118........
# Processing zipcode 735: 36853........
# Processing zipcode 736: 35020........
# Processing zipcode 737: 33147........
# Processing zipcode 738: 08302........
# Processing zipcode 739: 02124........
# Processing zipcode 743: 36522........
# Can't find 745 zipcode
# Processing zipcode 748: 90043........
# Processing zipcode 750: 11418........
# Processing zipcode 752: 32206........
# Processing zipcode 753: 75238........
# Processing zipcode 754: 19144........
# Processing zipcode 755: 60201........
# Processing zipcode 759: 90003........
# Processing zipcode 762: 60624........
# Processing zipcode 763: 19608........
# Processing zipcode 766: 38107........
# Processing zipcode 768: 33023........
# Processing zipcode 769: 47713........
# Processing zipcode 770: 33189........
# Processing zipcode 773: 98275........
# Can't find 774 zipcode
# Processing zipcode 775: 30601........
# Can't find 777 zipcode
# Processing zipcode 778: 60609........
# Can't find 783 zipcode
# Processing zipcode 784: 78602........
# Processing zipcode 785: 60901........
# Processing zipcode 786: 60638........
# Processing zipcode 787: 93727........
# Processing zipcode 788: 72301........
# Processing zipcode 790: 48208........
# Processing zipcode 794: 92405........
# Processing zipcode 803: 21217........
# Processing zipcode 809: 37620........
# Processing zipcode 810: 90011........
# Processing zipcode 812: 15222........
# Processing zipcode 813: 60636........
# Processing zipcode 814: 44102........
# Processing zipcode 816: 85041........
# Processing zipcode 819: 60643........
# Processing zipcode 820: 89108........
# Processing zipcode 821: 90061........
# Processing zipcode 822: 60623........
# Can't find 824 zipcode
# Processing zipcode 828: 78405........
# Processing zipcode 831: 60643........
# Can't find 832 zipcode
# Processing zipcode 833: 06120........
# Can't find 835 zipcode
# Can't find 836 zipcode
# Processing zipcode 837: 60612........
# Processing zipcode 838: 08046........
# Processing zipcode 841: 23350........
# Processing zipcode 842: 31501........
# Processing zipcode 843: 60649........
# Processing zipcode 844: 19805........
# Processing zipcode 846: 93702........
# Processing zipcode 847: 11203........
# Processing zipcode 848: 60624........
# Processing zipcode 852: 28262........
# Processing zipcode 853: 95204........
# Processing zipcode 855: 32547........
# Processing zipcode 856: 20001........
# Processing zipcode 858: 93277........
# Processing zipcode 860: 33914........
# Processing zipcode 862: 11224........
# Processing zipcode 864: 60624........
# Processing zipcode 866: 21212........
# Processing zipcode 868: 89101........
# Processing zipcode 870: 46225........
# Processing zipcode 874: 95202........
# Can't find 876 zipcode
# Processing zipcode 877: 46218........
# Can't find 880 zipcode
# Can't find 881 zipcode
# Processing zipcode 884: 60619........
# Processing zipcode 885: 78753........
# Processing zipcode 889: 71107........
# Processing zipcode 890: 33125........
# Processing zipcode 891: 55411........
# Processing zipcode 893: 63135........
# Processing zipcode 896: 39747........
# Processing zipcode 897: 20747........
# Processing zipcode 901: 60636........
# Processing zipcode 902: 80202........
# Processing zipcode 903: 89142........
# Processing zipcode 904: 36804........
# Processing zipcode 905: 10030........
# Processing zipcode 907: 45661........
# Processing zipcode 911: 60632........
# Processing zipcode 912: 60620........
# Processing zipcode 913: 90813........
# Processing zipcode 916: 78504........
# Processing zipcode 919: 36330........
# Processing zipcode 920: 53218........
# Processing zipcode 921: 90003........
# Processing zipcode 922: 38115........
# Processing zipcode 923: 36201........
# Processing zipcode 925: 60649........
# Processing zipcode 926: 60636........
# Processing zipcode 927: 60624........
# Processing zipcode 929: 60644........
# Processing zipcode 930: 33325........
# Processing zipcode 931: 36092........
# Can't find 932 zipcode
# Processing zipcode 933: 33907........
# Can't find 935 zipcode
# Processing zipcode 937: 08618........
# Processing zipcode 939: 78202........
# Processing zipcode 941: 66106........
# Processing zipcode 944: 90220........
# Processing zipcode 948: 91752........
# Processing zipcode 949: 22192........
# Processing zipcode 964: 35462........
# Processing zipcode 966: 39571........
# Processing zipcode 969: 60621........
# Processing zipcode 971: 32703........
# Processing zipcode 974: 85303........
# Processing zipcode 976: 98134........
# Processing zipcode 979: 23061........
# Processing zipcode 981: 20003........
# Processing zipcode 982: 60623........
# Processing zipcode 985: 80126........
# Processing zipcode 989: 33147........
# Processing zipcode 990: 39183........
# Processing zipcode 992: 70535........
# Processing zipcode 993: 35203........
# Processing zipcode 994: 70506........
# Can't find 996 zipcode
# Processing zipcode 998: 43207........
# Processing zipcode 999: 40210........
# Can't find 1001 zipcode
# Processing zipcode 1006: 48213........
# Processing zipcode 1015: 93725........
# Processing zipcode 1016: 30303........
# Processing zipcode 1018: 70117........
# Processing zipcode 1020: 45417........
# Processing zipcode 1021: 19145........
# Processing zipcode 1023: 78758........
# Processing zipcode 1026: 55404........
# Processing zipcode 1027: 90248........
# Processing zipcode 1029: 70445........
# Processing zipcode 1032: 23803........
# Processing zipcode 1034: 94115........
# Processing zipcode 1035: 95423........
# Processing zipcode 1036: 06114........
# Processing zipcode 1040: 19013........
# Processing zipcode 1041: 33603........
# Can't find 1044 zipcode
# Processing zipcode 1046: 85037........
# Processing zipcode 1047: 92656........
# Processing zipcode 1049: 94110........
# Processing zipcode 1051: 85037........
# Processing zipcode 1052: 60620........
# Processing zipcode 1053: 85122........
# Processing zipcode 1054: 33147........
# Processing zipcode 1062: 21225........
# Processing zipcode 1067: 61832........
# Processing zipcode 1070: 48208........
# Processing zipcode 1075: 17401........
# Processing zipcode 1076: 19133........
# Processing zipcode 1079: 36701........
# Processing zipcode 1080: 60612........
# Processing zipcode 1082: 90304........
# Processing zipcode 1084: 60620........
# Processing zipcode 1090: 60644........
# Can't find 1091 zipcode
# Processing zipcode 1093: 07103........
# Processing zipcode 1094: 21215........
# Processing zipcode 1096: 11236........
# Processing zipcode 1097: 60643........
# Processing zipcode 1099: 11798........
# Processing zipcode 1100: 91601........
# Processing zipcode 1101: 19104........
# Processing zipcode 1105: 60653........
# Processing zipcode 1106: 10469........
# Can't find 1107 zipcode
# Processing zipcode 1112: 59050........
# Processing zipcode 1114: 21205........
# Processing zipcode 1115: 60651........
# Processing zipcode 1117: 93706........
# Processing zipcode 1118: 62521........
# Processing zipcode 1123: 19801........
# Processing zipcode 1124: 60649........
# Processing zipcode 1127: 60619........
# Processing zipcode 1131: 90061........
# Processing zipcode 1132: 53210........
# Processing zipcode 1133: 08611........
# Processing zipcode 1134: 85335........
# Processing zipcode 1135: 19146........
# Processing zipcode 1136: 60643........
# Processing zipcode 1140: 39301........
# Processing zipcode 1141: 31401........
# Processing zipcode 1142: 60628........
# Processing zipcode 1144: 32809........
# Processing zipcode 1147: 36067........
# Processing zipcode 1149: 07305........
# Can't find 1150 zipcode
# Processing zipcode 1151: 60954........
# Processing zipcode 1152: 07102........
# Processing zipcode 1153: 94602........
# Processing zipcode 1156: 60644........
# Processing zipcode 1159: 33311........
# Processing zipcode 1160: 10026........
# Processing zipcode 1161: 08046........
# Processing zipcode 1163: 63106........
# Processing zipcode 1165: 60651........
# Processing zipcode 1167: 60644........
# Processing zipcode 1172: 44714........
# Processing zipcode 1176: 63130........
# Processing zipcode 1177: 60623........
# Processing zipcode 1178: 37406........
# Processing zipcode 1181: 76104........
# Processing zipcode 1187: 90003........
# Processing zipcode 1189: 63120........
# Processing zipcode 1191: 40202........
# Processing zipcode 1194: 39563........
# Processing zipcode 1198: 33054........
# Processing zipcode 1201: 19132........
# Processing zipcode 1205: 33825........
# Processing zipcode 1208: 66103........
# Processing zipcode 1209: 60632........
# Can't find 1215 zipcode
# Processing zipcode 1216: 29569........
# Processing zipcode 1217: 90033........
# Processing zipcode 1221: 90222........
# Processing zipcode 1224: 07106........
# Processing zipcode 1225: 33032........
# Processing zipcode 1227: 40203........
# Processing zipcode 1233: 46225........
# Processing zipcode 1236: 92220........
# Processing zipcode 1243: 60644........
# Processing zipcode 1245: 19122........
# Processing zipcode 1247: 60624........
# Processing zipcode 1251: 73107........
# Processing zipcode 1254: 44103........
# Processing zipcode 1257: 37921........
# Processing zipcode 1259: 44104........
# Processing zipcode 1260: 93727........
# Processing zipcode 1267: 70122........
# Processing zipcode 1268: 60620........
# Processing zipcode 1270: 66605........
# Processing zipcode 1275: 23606........
# Processing zipcode 1281: 39364........
# Processing zipcode 1283: 23504........
# Processing zipcode 1284: 19139........
# Processing zipcode 1290: 32331........
# Processing zipcode 1291: 60644........
# Processing zipcode 1292: 38372........
# Processing zipcode 1293: 70113........
# Processing zipcode 1298: 39194........
# Processing zipcode 1300: 20032........
# Processing zipcode 1301: 55429........
# Can't find 1303 zipcode
# Processing zipcode 1306: 60619........
# Can't find 1307 zipcode
# Processing zipcode 1308: 60636........
# Can't find 1313 zipcode
# Processing zipcode 1314: 93702........
# Can't find 1317 zipcode
# Processing zipcode 1321: 07105........
# Processing zipcode 1322: 60632........
# Processing zipcode 1324: 91103........
# Processing zipcode 1328: 38781........
# Processing zipcode 1330: 33147........
# ---------------
# Finished Processing
# ---------------

# %%
# Check to see how many unidentifiable
remaining = shooting_data[shooting_data.Zipcode == "NaN"]
len(remaining)
# Out:
# 75

# %%
# Check values of remaining to see why
remaining.head(25)
# Out:
#     Incident Date           State     City Or County  \
# 6      2014-12-22        Michigan            Detroit
# 28     2014-11-23        Virginia           Parksley
# 35     2014-11-18          Nevada    North Las Vegas
# 49     2014-10-18        New York           Brooklyn
# 56     2014-10-08         Georgia            Atlanta
# 67     2014-09-26  South Carolina  Darlington County
# 71     2014-09-18         Florida               Bell
# 98     2014-08-13       Louisiana        New Orleans
# 99     2014-08-12         Georgia       Cartersville
# 102    2014-08-10         Georgia       Wrightsville
# 116    2014-08-02   Massachusetts        New Bedford
# 122    2014-07-26        Arkansas         Pine Bluff
# 132    2014-07-14      California         Sacramento
# 172    2014-06-07  South Carolina      Moncks Corner
# 175    2014-06-03         Georgia            Atlanta
# 181    2014-05-24        Michigan            Detroit
# 192    2014-05-11      California         Sacramento
# 195    2014-05-10      California         Sacramento
# 220    2014-03-30     Mississippi         Starkville
# 226    2014-03-16           Texas           Beaumont
# 234    2014-03-01    Pennsylvania         Pittsburgh
# 248    2014-02-12      California           Stockton
# 249    2014-02-07         Florida              Miami
# 257    2014-01-21      New Jersey             Newark
# 264    2014-01-12         Alabama         Huntsville
#
#                                       Address  # Killed  # Injured  \
# 6                       Charlevoix and Philip         1          3
# 28                              Parksley Road         0          4
# 35                           Englestad Street         0          4
# 49                                 Lenox Road         0          4
# 56          Auburn Avenue and Edgewood Avenue         0          4
# 67                   600 block of Turner Road         1          4
# 71         NW 30th Street and NW 39th Terrace         8          0
# 98   New Orleans and North Rocheblave streets         0          4
# 99                                  Brent Cir         2          3
# 102                               Idylwild Dr         0          6
# 116                           Acushnet Avenue         0          7
# 122                   Third Ave and Redbud St         1          3
# 132                            Fulton Avenue          1          4
# 172                                 Tish Lane         1          5
# 175                             Auburn Avenue         1          4
# 181                         Strathmoor Street         0          4
# 192                            Peregrine Park         1          6
# 195                                   Natomas         1          6
# 220                                       NaN         0          5
# 226                                  S 4th St         3          1
# 234                           Hamilton Avenue         1          4
# 248                         Constitution Park         1          3
# 249     Northwest 41st Street and 9th Avenue          0          5
# 257                       Springfield Avenue          2          3
# 264                          University Drive         0          5
#
#      Operations  ST Zipcode
# 6           NaN  MI     NaN
# 28          NaN  VA     NaN
# 35          NaN  NV     NaN
# 49          NaN  NY     NaN
# 56          NaN  GA     NaN
# 67          NaN  SC     NaN
# 71          NaN  FL     NaN
# 98          NaN  LA     NaN
# 99          NaN  GA     NaN
# 102         NaN  GA     NaN
# 116         NaN  MA     NaN
# 122         NaN  AR     NaN
# 132         NaN  CA     NaN
# 172         NaN  SC     NaN
# 175         NaN  GA     NaN
# 181         NaN  MI     NaN
# 192         NaN  CA     NaN
# 195         NaN  CA     NaN
# 220         NaN  MS     NaN
# 226         NaN  TX     NaN
# 234         NaN  PA     NaN
# 248         NaN  CA     NaN
# 249         NaN  FL     NaN
# 257         NaN  NJ     NaN
# 264         NaN  AL     NaN

# %%
# Drop rows with zipcodes that are unidentifiable
shooting_data = shooting_data[shooting_data.Zipcode != "NaN"]

# Veryify number of incidents are correct
len(shooting_data)
# Out:
# 1256

# %%
# Drop Operations column
shooting_data = shooting_data.drop(["Operations"],axis = 1 )

# %%
# Replace state names with abbreviations and drop abbreviations column
shooting_data["State"] = shooting_data["ST"]
shooting_data = shooting_data.drop(["ST"], axis = 1)

# %%
# Preview and verify dataframe
shooting_data.head(50)
# Out:
#    Incident Date State     City Or County  \
# 0     2014-12-29    LA        New Orleans
# 1     2014-12-27    CA        Los Angeles
# 2     2014-12-27    CA         Sacramento
# 3     2014-12-26    IL     East St. Louis
# 4     2014-12-24    MO        Saint Louis
# 5     2014-12-23    KY         Winchester
# 7     2014-12-22    NY            Webster
# 8     2014-12-22    IL            Chicago
# 9     2014-12-21    FL           Sarasota
# 10    2014-12-21    MS         Waynesboro
# 11    2014-12-21    IL       Calumet City
# 12    2014-12-20    IL           Rockford
# 13    2014-12-16    NJ          Elizabeth
# 14    2014-12-15    PA           Lansdale
# 15    2014-12-14    FL              Miami
# 16    2014-12-13    FL              Tampa
# 17    2014-12-12    OR           Portland
# 18    2014-12-07    IN         South Bend
# 19    2014-12-02    MO        Saint Louis
# 20    2014-12-02    VA       Newport News
# 21    2014-11-30    NY           Brooklyn
# 22    2014-11-30    TN        Chattanooga
# 23    2014-11-29    NJ             Newark
# 24    2014-11-29    GA            Atlanta
# 25    2014-11-28    TN            Memphis
# 26    2014-11-27    TX         Georgetown
# 27    2014-11-26    CA      San Francisco
# 29    2014-11-23    CO             Denver
# 30    2014-11-22    OH          Cleveland
# 31    2014-11-22    SD           Sisseton
# 32    2014-11-22    OH        Springfield
# 33    2014-11-21    PA         Pittsburgh
# 34    2014-11-19    IL            Chicago
# 36    2014-11-16    OH              Akron
# 37    2014-11-16    TX            El Paso
# 38    2014-11-15    MO        Springfield
# 39    2014-11-15    FL              Miami
# 40    2014-11-08    CA             Pomona
# 41    2014-11-07    CA            Compton
# 42    2014-11-07    CA        Los Angeles
# 43    2014-11-05    CA      San Francisco
# 44    2014-10-29    TN            Memphis
# 45    2014-10-26    KY              Cadiz
# 46    2014-10-24    WA         Marysville
# 47    2014-10-18    NY             Queens
# 48    2014-10-18    SC       Graniteville
# 50    2014-10-16    MI            Detroit
# 51    2014-10-14    GA  Peachtree Corners
# 52    2014-10-13    GA            Atlanta
# 53    2014-10-12    CA           Stockton
#
#                                        Address  # Killed  # Injured Zipcode
# 0                          Poydras and Bolivar         0          4   70113
# 1          8800 block of South Figueroa Street         1          3   90003
# 2                     4000 block of May Street         0          4   95838
# 3                  2500 block of Summit Avenue         1          3   62205
# 4                                18th and Pine         1          3   63103
# 5                             260 Oxford Drive         1          3   40391
# 7                                191 Lake Road         4          2   14580
# 8             5700 block of South Green Street         0          5   60621
# 9                       4034 N Washington Blvd         2          2   34234
# 10                              Central Avenue         1          4   39367
# 11                        600 block of Escanba         1          8   60409
# 12               3200 block of Montrose Avenue         4          0   61101
# 13                                 Anna Street         0          4   07201
# 14                    100 block of West 5th St         7          0   19446
# 15                   1311 Northwest 2nd Avenue         1          4   33136
# 16                         810 E. Skagway Ave.         0          5   33604
# 17               717 North Killingsworth Court         0          4   97217
# 18               16000 block of Roosevelt Road         0          4   46614
# 19               6000 block of Virginia Avenue         1          5   63111
# 20                         6128 Jefferson Ave          0          5   23605
# 21                           375 Remsen Avenue         0          4   11212
# 22                      2412 East 13th Street          0          5   37404
# 23                            348 S Orange Ave         1          3   07103
# 24               1600 block of Richmond Avenue         3          2   30315
# 25                      1849 East Brooks Road          0          4   38116
# 26                                  Pvt Rd 934         2          3   78626
# 27                    Mission and 13th streets         0          6   94103
# 29           Federal Boulevard and 16th Avenue         1          4   80204
# 30                              1443 E 92nd St         4          1   44106
# 31                               Fourth Avenue         4          1   57262
# 32              Clifton Avenue and Rice Street         1          3   45505
# 33                  600 block of Miller Avenue         0          6   15122
# 34         700 block of North St. Louis Avenue         1          3   60624
# 36                            1891 E Market St         1          4   44305
# 37                              115 S. Durango         0          6   79901
# 38                           2555 N. Glenstone         4          0   65803
# 39                            NW 55th and 12th         1          3   33142
# 40                        499 E. Arrow Highway         0          5   91767
# 41                               136th Street          0          4   90222
# 42  East 126th Street and North Compton Avenue         0          4   90222
# 43               1100 block of Alabama Street          0          4   94110
# 44                   Yale Road and Ramill Road         0          5   38128
# 45                         1410 Old Dover Road         4          0   42211
# 46                            5611 108th St NE         5          1   98271
# 47                           33-02 Queens Blvd         0          4   11101
# 48                        192 Breezy Hill Road         1          3   29829
# 50                                Mogul Street         1          3   48224
# 51                            6505 Bannor Lane         3          2   30092
# 52                          85 Mount Zion Road         0          4   30354
# 53               1100 block of East March Lane         3          1   95210

# %%
# Save to csv file
shooting_data.to_csv("OutputFiles/ZipcodeData.csv")
